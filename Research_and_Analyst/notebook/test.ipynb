# %%
print("all ok")
# Out:
# all ok

# %%
import sys, os 
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_root)
print('Project root added to the path', project_root)
# Out:
# Project root added to the path c:\Users\rohit\Desktop\Rohit\2026\Learning\Krish Naik\LLM OPS Project\agentic-reportcraft

# %%
from typing import List
from typing_extensions import TypedDict
from pydantic import BaseModel, Field

# %%
print(os.getcwd())
# print(sys.path)
# Out:
# c:\Users\rohit\Desktop\Rohit\2026\Learning\Krish Naik\LLM OPS Project\agentic-reportcraft\research_and_analyst\notebook

# %%
# os.chdir(project_root)
# print(os.getcwd())
# # print(sys.path

# %%
import os
import sys
import json
import asyncio
from dotenv import load_dotenv
# from utils.config_loader import load_config
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
# from research_and_analyst.logger import GLOBAL_LOGGER as log
# from exception.custom_exception import ResearchAnalystException

# %%
# from research_and_analyst.utils.model_loader import ModelLoader

# %%
llm = load_llm()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 llm = load_llm()
#
# Cell In[21], line 61, in load_llm()
#      56     return llm
#      58 except Exception as e:
#      59     # log.error("Error loading LLM", error=str(e))
#      60     # raise ResearchAnalystException("Failed to load LLM", sys)
# ---> 61     raise e
#
# Cell In[21], line 14, in load_llm()
#       2 """
#       3 Load and return a chat-based LLM according to the configured provider.
#       4
#    (...)     11     ChatOpenAI | ChatGoogleGenerativeAI | ChatGroq: LLM instance
#      12 """
#      13 try:
# ---> 14     llm_block = config["llm"]
#      15     provider_key = os.getenv("LLM_PROVIDER", "openai")
#      17     if provider_key not in llm_block:
#
# NameError: name 'config' is not defined

# %%
from research_and_analyst.utils import model_loader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from research_and_analyst.utils import model_loader
#
# File c:\Users\rohit\Desktop\Rohit\2026\Learning\Krish Naik\LLM OPS Project\agentic-reportcraft\research_and_analyst\utils\model_loader.py:6
#       4 import asyncio
#       5 from dotenv import load_dotenv
# ----> 6 from utils.config_loader import load_config
#       7 from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
#       8 from langchain_openai import ChatOpenAI
#
# ModuleNotFoundError: No module named 'utils'

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
from research_and_analyst.utils.model_loader import ModelLoader
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from research_and_analyst.utils.model_loader import ModelLoade
#
# ImportError: cannot import name 'ModelLoade' from 'research_and_analyst.utils.model_loader' (c:\Users\rohit\Desktop\Rohit\2026\Learning\Krish Naik\LLM OPS Project\agentic-reportcraft\research_and_analyst\utils\model_loader.py)

# %%
model_loader = ModelLoader()
()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model_loader = ModelLoader()
#       2 ()
#
# NameError: name 'ModelLoader' is not defined

# %%
def create_analyst(state):
    pass

# %%
def human_feedback(state):
    pass

# %%
def should_continue(state):
    pass

# %%
from langgraph.graph import StateGraph, START, END
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from langgraph.checkpoint import MemorySaver

# %%
from IPython.display import Image, display

# %%
builder = StateGraph()

# %%
builder.add_nodes()
builder.add_nodes()

# %%
builder.edge(START, create_analyst)
builder.add_edge("create_analyst", "human_feedback")
builder.add_conditional_edges("human_feedback",
                              "create_analyst",
                              END)

# %%
memory  = MemorySaver()

# %%
graph = builder.compile(interrupt_before=["human_feedback"],checkpointer=memory)

# %%
display(Image(graph.get_graph(xray=1).draw_mermaid.png()))
